# %%
import glob
import numpy as np

# Path to the directory with CSV files
dataset_dir = "../HardwareData"
files = glob.glob(f"{dataset_dir}/*.npy")

print(files[0])
data = np.load(files[0])
len(data[0])
# Out:
# ../HardwareData/ENC_DES_1024_trials_2024-12-19-18-04-32.npy
# 10000

# %%
import matplotlib.pyplot as plt

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(data[0][:1000], label="Signal")
plt.xlabel("Time (s)")
plt.ylabel("Signal Amplitude")
plt.title("DPA Contest Signal Data")
plt.legend()
plt.grid(True)
plt.show()
